# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/harshilpatel/Desktop/Healthcare-Monitoring-Platform/data/raw/heart.csv")
df['age'].hist()
plt.show()
df['age'].mean()
# Out:
# np.float64(54.43414634146342)

# %%
df['chol'].hist()
plt.show()
df['chol'].mean()
# Out:
# np.float64(246.0)

# %%
df['thalach'].hist()
plt.show()
df['thalach'].mean()
# Out:
# np.float64(149.11414634146342)

# %%
df['target'].value_counts().plot(kind='bar')
plt.show()
